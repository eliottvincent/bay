# %%
import numpy as np
import plotly.express as px
import pandas as pd

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x)

# %%
# %matplotlib inline
f = plt.figure(figsize=(8,4))
plt.plot(x, y)
plt.grid(ls=':')
